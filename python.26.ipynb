# %%
print('hello,world')
# Out:
# hello,world

# %%
print('hello , shyam')
# Out:
# hello , shyam

# %%
input('enter your input')
# Out:
# enter your inputshyam
# 'shyam'

# %%
name=input('Enter your name :')
print('hello',name)
# Out:
# Enter your name :bro
# hello bro

# %%
age=int(input('Enter your age :'))
print('priya',age)
# Out:
# Enter your age :17
# priya 17
