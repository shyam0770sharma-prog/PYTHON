# %% [markdown]
# <a href="https://colab.research.google.com/github/shyam0770sharma-prog/PYTHON/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
var = "saras"
index = 0
end = len(var)-1
a = False
while index < len(var):
    if var[index] != var[end]:
        a = True
        break

    index += 1
    end -= 1

if(a==True):
    print("not a palindrom")
else:
    print("palindrom")
# Out:
# palindrom

# %%
#Q1. Find the second-highest salary
salaries = [50000, 70000, 45000, 90000, 70000, 80000]
HighesSalary=0
SecondHighest=0
for i in range(0,len(salaries)):
  if salaries[i] > HighesSalary:
    SecondHighest=HighesSalary
    HighesSalary=salaries[i]
  elif salaries[i]>SecondHighest and salaries[i] != HighesSalary:
      SecondHighest=salaries[i]
print(SecondHighest)
# Out:
# 80000

# %%
#Q2. Find duplicate values
numbers = [10, 20, 10, 30, 40, 20, 50, 30]
original=[]
duplicate=[]
for i in numbers:
 if i in original:
   duplicate.append(i)
 else:
    original.append(i)
print(duplicate)
# Out:
# [10, 20, 30]

# %%
#Q3. Count frequency of each value
names = ["Ram", "Shyam", "Ram", "Mohan", "Shyam", "Ram"]
dict = {}
for i in names:
  if i in dict:
    dict[i]+=1
  else:
    dict[i]=1
print(dict)
# Out:
# {'Ram': 3, 'Shyam': 2, 'Mohan': 1}

# %%
#Q4. Find the maximum profit
prices = [10, 7, 6, 14, 8, 13]

left = 0
right = 1

max_profit = 0

while right < len(prices):

    if prices[left] < prices[right]:

        profit = prices[right] - prices[left]

        if profit > max_profit:
            max_profit = profit

    else:
        left = right

    right += 1

print(max_profit)
# Out:
# 8

# %%
from numpy import average
#Q5. Pandas interview question
#Task: Find the average salary of each department.
#Given:
import pandas as pd

df = pd.DataFrame({
    "Name": ["A", "B", "C", "D"],
    "Department": ["IT", "HR", "IT", "HR"],
    "Salary": [50000, 40000, 70000, 60000]
})
avg_salary=df.groupby("Department")["Salary"].mean()

# %%
avg_salary
# Out:
# Department
# HR    50000.0
# IT    60000.0
# Name: Salary, dtype: float64

# %%
import pandas as pd

df = pd.DataFrame({
    "Name": ["Shyam", "Rahul", None, "Amit"],
    "Age": [25, None, 28, None],
    "Salary": [50000, 60000, None, 70000]
})

# %%
# explain
# **Q1. Missing Values**
# Given a DataFrame `df`, find the number of missing values in each column.
df.isnull().sum()
# Out:
# Name      1
# Age       2
# Salary    1
# dtype: int64

# %%
# Q2. Department Salary
# Find the average salary for each department
df['Salary'].mean()
# Out:
# np.float64(60000.0)

# %%
import pandas as pd

data = {
    "EmployeeID": [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    "Name": ["Shyam", "Rahul", "Amit", "Priya", "Neha",
             "Vikas", "Anjali", "Rohit", "Karan", "Pooja"],
    "Department": ["IT", "IT", "HR", "HR", "Finance",
                   "Finance", "IT", "HR", "Finance", "IT"],
    "Age": [25, None, 28, 32, None, 30, 26, None, 29, 27],
    "Salary": [85000, 90000, None, 65000, 75000,
               80000, 95000, 70000, None, 88000]
}

df = pd.DataFrame(data)

df
# Out:
#    EmployeeID    Name Department   Age   Salary
# 0         101   Shyam         IT  25.0  85000.0
# 1         102   Rahul         IT   NaN  90000.0
# 2         103    Amit         HR  28.0      NaN
# 3         104   Priya         HR  32.0  65000.0
# 4         105    Neha    Finance   NaN  75000.0
# 5         106   Vikas    Finance  30.0  80000.0
# 6         107  Anjali         IT  26.0  95000.0
# 7         108   Rohit         HR   NaN  70000.0
# 8         109   Karan    Finance  29.0      NaN
# 9         110   Pooja         IT  27.0  88000.0

# %%
# Q2. Department Salary
# Find the average salary for each department
df.groupby('Department')['Salary'].mean()
# Out:
# Department
# Finance    77500.0
# HR         67500.0
# IT         89500.0
# Name: Salary, dtype: float64

# %%
# Q3. Highest Salary
# Find the top 5 employees by salary.
df.sort_values(by='Salary', ascending=False).head(5)
# Out:
#    EmployeeID    Name Department   Age   Salary
# 6         107  Anjali         IT  26.0  95000.0
# 1         102   Rahul         IT   NaN  90000.0
# 9         110   Pooja         IT  27.0  88000.0
# 0         101   Shyam         IT  25.0  85000.0
# 5         106   Vikas    Finance  30.0  80000.0

# %%
# Q4. Duplicate Employees
# Find duplicate rows based on EmployeeID.

df[df.duplicated(subset='EmployeeID', keep=False)]
# Out:
# Empty DataFrame
# Columns: [EmployeeID, Name, Department, Age, Salary]
# Index: []

# %%
# Q5. Outliers
# Using the IQR method, identify salary outliers

Q1 = df['Salary'].quantile(0.25)
Q3 = df['Salary'].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

df[(df['Salary'] < lower) | (df['Salary'] > upper)]
Q1
Q3
# Out:
# np.float64(88500.0)

# %%
df[(df['Salary'] < lower) | (df['Salary'] > upper)]
Q1
Q3
# Out:
# np.float64(88500.0)

# %%
Q1
Q3
# Out:
# np.float64(88500.0)
