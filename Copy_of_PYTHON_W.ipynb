# %% [markdown]
# <a href="https://colab.research.google.com/github/shyam0770sharma-prog/PYTHON/blob/main/Copy_of_PYTHON_W.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello,world')
# Out:
# hello,world

# %%
print('hello , shyam')
# Out:
# hello , shyam

# %%
input('enter your input')
# Out:
# enter your inputshyam
# 'shyam'

# %%
name=input('Enter your name :')
print('hello',name)
# Out:
# Enter your name :bro
# hello bro

# %%
age=int(input('Enter your age :'))
print('priya',age)
# Out:
# Enter your age :17
# priya 17

# %%
a=20
print(type(a))
b=2.7
print(type(b))
c=4+4j
print(type(c))
d=True
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'bool'>

# %%
#sequence data type
#why sequence ? into data type the data is stored into the sequence
#mutable
li=[1,2,3]
print(type(li))
#tuples-> immutable ->ones created the tuple then can't chenge that
#after the creation of the tuple
t=(1,2,3)
print(type(t))
# string -> immutable
name='shyam'
print(type(name))
r=range(1,20)
print(type(r))
# set ->set contains the unique values it means it doesn't contain
#any duplicate values
#the set is mutable
#unordered -> we can't access this using any indices.
#initialising the set
# var ={1,2,3}
var={1,2,3}
print(type(var))
# Out:
# <class 'list'>
# <class 'tuple'>
# <class 'str'>
# <class 'range'>
# <class 'set'>

# %%
#None
n= None
print(type(n))
# Out:
# <class 'NoneType'>

# %%
# Dictionary data type is used to store the key and value pairs
# Dictionary is ordered
#Dictionary mutable but the key are immutable
# Initialising dict-> d={'key':'value'}



d={'name':'shyam','roll':25}
print(type(d))
# Out:
# <class 'dict'>

# %%
a=int(input('Enter a num'))
b=int(input('Enter a num'))
print(a+b)
# Out:
# Enter a num20
# Enter a num30
# 50

# %%
a=30
b=20
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
a=2
b=4
print(a**b)
# Out:
# 50
# 10
# 600
# 1.5
# 1
# 16

# %%
a=20
b=30
print(a<b)
print(a>b)
print(a==b)
print(a!=b)
print(a<=b)
print(a>=b)
# Out:
# True
# False
# False
# True
# True
# False

# %%
a=10
b=20
c=30
print(a<b)
print(b>c)
print(a<b and b<c)

print(a<b or b>c)
is_prime=True
print(not is_prime)
# Out:
# True
# False
# True
# True
# False

# %%
## membership opretor
li=[1,2,3,4]
4 in li
5 not in li
5 in li
# Out:
# False

# %%
a=20
a+=20
print(a)
a-=20
print(a)
a*=20
print(a)
a/=20
print(a)
a//=20
print(a)
# Out:
# 40
# 20
# 400
# 20.0
# 1.0

# %%
a=20
b=20
c=8
print(id(a))
print(id(b))
print(id(c))
a is b
b is c
a is not b
a is not c
# Out:
# 11645960
# 11645960
# 11645576
# True

# %%
age=19
if(age<=18):
  print("qualify")
else:
  print("not qualify")
# Out:
# not qualify

# %%
x=40
if(x<35):
  print("value is greater")
else:
  print("value is smaller")
# Out:
# value is smaller

# %%
x=18
if(x%2==0 and x%3==0):
  print("dvided by both")
else:
  print("not dvided by both")
# Out:
# dvided by both

# %%
x=16
if(x%5==0 or x<15):
  print("true")
else:
  print("fales")
# Out:
# fales

# %%
x=66
if(x>40 and x<=60):
  print("number is ok")
else:
  print("number is not ok")
# Out:
# number is not ok

# %%
name=input("Enter your name :")
age=int(input("Enter your age :"))
if(age>=18):
  print("your qualify")
else:
   print("your not qualify")
# Out:
# Enter your name :shyam
# Enter your age :18
# your qualify
