# %% [markdown]
# <a href="https://colab.research.google.com/github/shyam0770sharma-prog/PYTHON/blob/main/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Classes
class shyamlist:
    def __init__(self):
        """Initialize an empty list."""
        self._items = []

    def add(self, item):
        """Add an item to the end of the list."""
        self._items.append(item)

    def __getitem__(self, index):
        """Retrieve an item by index."""
        return self._items[index]

    def __setitem__(self, index, value):
        """Set an item at a specific index."""
        self._items[index] = value

    def __repr__(self):
        """Return a string representation of the list."""
        return str(self._items)

    def __len__(self):
        """Return the length of the list."""
        return len(self._items)

# %%
my_list=shyamlist()

# %%
my_list
# Out:
# []

# %%
my_list.add("vanshika")

# %%
my_list
# Out:
# ['vanshika']

# %%
my_list.add("data analyst")

# %%
my_list
# Out:
# ['vanshika', 'data analyst']

# %%
len(my_list)
# Out:
# 2

# %%
class BaseSalary:
    def __init__(self, base_salary, bonus_rate=0.1, symbol='$'):
        self.base_salary = base_salary
        self.bonus_rate = bonus_rate
        self.symbol = symbol
        self.total_salary = base_salary * (1 + bonus_rate)
        self.bonus = self.total_salary - self.base_salary

    def __repr__(self):
        return f'{self.symbol}{self.base_salary:,.0f}'

    def show_salary(self):
        return f'{self.symbol}{self.total_salary:,.0f}'

    def show_bonus(self):
        return f'{self.symbol}{self.bonus:,.0f}'

# %%
salary = BaseSalary(100000)

salary.symbol
# Out:
# '$'

# %%
salary
# Out:
# $100,000

# %%
salary.show_salary()
# Out:
# '$110,000'

# %%
salary.show_bonus()
# Out:
# '$10,000'

# %%
# a list of salaries ranging from 50,000  to 150,000

import random

salary_list = [random.randint(50000, 100000) for _ in range(10_000_000)]

# %%
import statistics

# %%
# %%timeit

statistics.median(salary_list)
# Out:
# 5.02 s ± 312 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import numpy as np

# %%
# %%timeit

np.median(salary_list)
# Out:
# 937 ms ± 284 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
my_array = np.array([1,2,3,4])

# %%
my_array.mean()
# Out:
# np.float64(2.5)

# %%
import numpy as np

# Job titles
job_titles = np.array(['Data Analyst', 'Data Scientist', 'Data Engineer', 'Machine Learning Engineer', 'AI Engineer'])

# Base salaries
base_salaries = np.array([60000, 80000, 75000, 90000, np.nan])

# Bonus rates
bonus_rates = np.array([.05, .1, .08, .12, np.nan])

# %%
total_salaries = base_salaries * (1 + bonus_rates)

total_salaries
# Out:
# array([ 63000.,  88000.,  81000., 100800.,     nan])

# %%
np.nanmean(total_salaries)
# Out:
# np.float64(83200.0)

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/california_housing_test.csv')

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df['total_bedrooms']
# Out:
# 0        661.0
# 1        310.0
# 2        507.0
# 3         15.0
# 4        244.0
#          ...
# 2995     642.0
# 2996    1082.0
# 2997     201.0
# 2998      14.0
# 2999     263.0
# Name: total_bedrooms, Length: 3000, dtype: float64

# %%
df.total_bedrooms
# Out:
# 0        661.0
# 1        310.0
# 2        507.0
# 3         15.0
# 4        244.0
#          ...
# 2995     642.0
# 2996    1082.0
# 2997     201.0
# 2998      14.0
# 2999     263.0
# Name: total_bedrooms, Length: 3000, dtype: float64

# %%
df.total_bedrooms[0]
# Out:
# np.float64(661.0)

# %%
df['total_bedrooms'][2999]
# Out:
# np.float64(263.0)

# %%
# !pip install datasets

# %%
from datasets import load_dataset

# %%
dataset=load_dataset('lukebarousse/data_jobs')

# %%
dataset['train']
# Out:
# Dataset({
#     features: ['job_title_short', 'job_title', 'job_location', 'job_via', 'job_schedule_type', 'job_work_from_home', 'search_location', 'job_posted_date', 'job_no_degree_mention', 'job_health_insurance', 'job_country', 'salary_rate', 'salary_year_avg', 'salary_hour_avg', 'company_name', 'job_skills', 'job_type_skills'],
#     num_rows: 785741
# })

# %%
df=dataset['train'].to_pandas()

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
import pandas as pd

# %%
from datasets import load_dataset

# loading data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
# Out:
# README.md:   0%|          | 0.00/3.25k [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# data_jobs.csv: reconstructing file:   0%|          |  0.00B /  231MB
# data_jobs.csv: downloading bytes:           |  0.00B
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df.head(10)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
# 5         Data Engineer                                  GCP Data Engineer
# 6  Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
# 7         Data Engineer                                      Data Engineer
# 8      Business Analyst           Technology & Operations Business Analyst
# 9        Data Scientist                                  Data Scientist II
#
#                    job_location             job_via         job_schedule_type  \
# ...

# %%
df['job_country'].head()
# Out:
# 0    United States
# 1           Mexico
# 2          Germany
# 3    United States
# 4            Sudan
# Name: job_country, dtype: object

# %%
df[['job_country','job_location']]
# Out:
#           job_country                         job_location
# 0       United States                        Watertown, CT
# 1              Mexico         Guadalajara, Jalisco, Mexico
# 2             Germany                      Berlin, Germany
# 3       United States                      San Antonio, TX
# 4               Sudan                       Washington, DC
# ...               ...                                  ...
# 785736      Singapore                            Singapura
# 785737        Germany                   Bad Rodach, Jerman
# 785738       Malaysia                             Malaysia
# 785739          Sudan  Newark, New Jersey, Amerika Serikat
# 785740          India                                India
#
# [785741 rows x 2 columns]

# %%
df[['job_country','job_location']].head()
# Out:
#      job_country                  job_location
# 0  United States                 Watertown, CT
# 1         Mexico  Guadalajara, Jalisco, Mexico
# 2        Germany               Berlin, Germany
# 3  United States               San Antonio, TX
# 4          Sudan                Washington, DC

# %%
df.iloc[20]
# Out:
# job_title_short                                             Data Scientist
# job_title                                                   Data Scientist
# job_location                                             Zaventem, Belgium
# job_via                                                 via BeBee Belgique
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                    Belgium
# job_posted_date                                        2023-01-31 13:53:38
# job_no_degree_mention                                                False
# job_health_insurance                                                 False
# job_country                                                        Belgium
# salary_rate                                                           None
# ...

# %%
df.iloc[20:30]
# Out:
#               job_title_short  \
# 20             Data Scientist
# 21             Data Scientist
# 22              Data Engineer
# 23  Machine Learning Engineer
# 24             Data Scientist
# 25        Senior Data Analyst
# 26              Data Engineer
# 27              Data Engineer
# 28             Data Scientist
# 29             Data Scientist
#
#                                             job_title  \
# 20                                     Data Scientist
# 21  Stage - data scientist – génération ia de donn...
# 22      Data Engineer / Développeur·euse Big Data F/H
# 23    PhD position in computer science (NLP, finance)
# 24                      Data Scientist (DataLab Team)
# 25                  Senior Officer, Data Analyst, GTO
# 26                                      Data Engineer
# 27  Principal Data Engineer (Lead), Knowledge Grap...
# 28                                CRM Data Specialist
# 29                                     Data Scientist
#
# ...

# %%
df.iloc[20:30,0:2]
# Out:
#               job_title_short  \
# 20             Data Scientist
# 21             Data Scientist
# 22              Data Engineer
# 23  Machine Learning Engineer
# 24             Data Scientist
# 25        Senior Data Analyst
# 26              Data Engineer
# 27              Data Engineer
# 28             Data Scientist
# 29             Data Scientist
#
#                                             job_title
# 20                                     Data Scientist
# 21  Stage - data scientist – génération ia de donn...
# 22      Data Engineer / Développeur·euse Big Data F/H
# 23    PhD position in computer science (NLP, finance)
# 24                      Data Scientist (DataLab Team)
# 25                  Senior Officer, Data Analyst, GTO
# 26                                      Data Engineer
# 27  Principal Data Engineer (Lead), Knowledge Grap...
# 28                                CRM Data Specialist
# 29                                     Data Scientist

# %%
df[['job_title_short','job_title']].iloc[0:5]
# Out:
#         job_title_short                                          job_title
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.describe()
# Out:
#        salary_year_avg  salary_hour_avg
# count     22003.000000     10662.000000
# mean     123286.274072        47.016598
# std       48312.449482        21.890738
# min       15000.000000         8.000000
# 25%       90000.000000        27.500000
# 50%      115000.000000        45.980000
# 75%      150000.000000        61.159996
# max      960000.000000       391.000000

# %%
df.job_title_short.unique()
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
df[(df.job_title_short == 'Data Analyst') | (df.salary_year_avg > 100000)]
# Out:
#        job_title_short                                          job_title  \
# 1         Data Analyst                                       Data Analyst
# 12        Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18        Data Analyst                                       Data Analyst
# 28      Data Scientist                                CRM Data Specialist
# 31        Data Analyst                           Stage - Data Analyst F/H
# ...                ...                                                ...
# 785703    Data Analyst            Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst          Expert Business Data Analyst - Now Hiring
# 785715    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 785717    Data Analyst                 Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                                   CRM Data Analyst
#
#                                    job_location  \
# ...

# %%
df[(df.job_title_short == 'Data Analyst') & (df.salary_year_avg.notna())]
# Out:
#        job_title_short                                    job_title  \
# 109       Data Analyst        Senior Supply Chain Analytics Analyst
# 180       Data Analyst                             Data Analyst III
# 410       Data Analyst  IT Business Lead Data Analyst - VP - Hybrid
# 988       Data Analyst                        DATA ANALYST (ONSITE)
# 1413      Data Analyst                          Junior BI Developer
# ...                ...                                          ...
# 784033    Data Analyst                     Recruitment Data Analyst
# 784423    Data Analyst                           Sales Data Analyst
# 784882    Data Analyst         Merchandising Analyst (Data Analyst)
# 785187    Data Analyst                                 Data Analyst
# 785515    Data Analyst                                 Data Analyst
#
#                        job_location                job_via job_schedule_type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.job_posted_date[0]
# Out:
# '2023-06-16 13:44:15'

# %%
type(df.job_posted_date[0])
# Out:
# str

# %%
pd.to_datetime(df.job_posted_date)
# Out:
# 0        2023-06-16 13:44:15
# 1        2023-01-14 13:18:07
# 2        2023-10-10 13:14:55
# 3        2023-07-04 13:01:41
# 4        2023-08-07 14:29:36
#                  ...
# 785736   2023-03-13 06:16:16
# 785737   2023-03-12 06:18:18
# 785738   2023-03-12 06:32:36
# 785739   2023-03-12 06:32:15
# 785740   2023-03-13 06:16:31
# Name: job_posted_date, Length: 785741, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df['job_posted_date'] = pd.to_datetime(df.job_posted_date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.job_posted_date.dt.month
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 785736    1
# 785737    1
# 785738    1
# 785739    1
# 785740    1
# Name: job_posted_date, Length: 785741, dtype: int32

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df['job_posted_date_month'] = df.job_posted_date.dt.month

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df.sort_values('job_posted_date')
# Out:
#                   job_title_short                          job_title  \
# 203943             Data Scientist                     Data Scientist
# 282667             Data Scientist                     Data Scientist
# 93472        Senior Data Engineer               Senior Data Engineer
# 93471              Data Scientist                  Data Scientist II
# 282665             Data Scientist    Material Data Specialist(Coupa)
# ...                           ...                                ...
# 413720             Data Scientist              Data Science- GPT/LLM
# 731675       Senior Data Engineer               Senior Data Engineer
# 467337          Software Engineer    Principal iOS Software Engineer
# 731685  Machine Learning Engineer  Machine-Learning-Engineer (m/w/d)
# 573693           Business Analyst                        QA Engineer
#
#                                          job_location            job_via  \
# ...

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df.sort_values(by= 'job_posted_date', inplace=True)

# %%
df
# Out:
#                   job_title_short                          job_title  \
# 203943             Data Scientist                     Data Scientist
# 282667             Data Scientist                     Data Scientist
# 93472        Senior Data Engineer               Senior Data Engineer
# 93471              Data Scientist                  Data Scientist II
# 282665             Data Scientist    Material Data Specialist(Coupa)
# ...                           ...                                ...
# 413720             Data Scientist              Data Science- GPT/LLM
# 731675       Senior Data Engineer               Senior Data Engineer
# 467337          Software Engineer    Principal iOS Software Engineer
# 731685  Machine Learning Engineer  Machine-Learning-Engineer (m/w/d)
# 573693           Business Analyst                        QA Engineer
#
#                                          job_location            job_via  \
# ...

# %%
df.drop(labels='salary_hour_avg',axis=1)
# Out:
#                   job_title_short                          job_title  \
# 203943             Data Scientist                     Data Scientist
# 282667             Data Scientist                     Data Scientist
# 93472        Senior Data Engineer               Senior Data Engineer
# 93471              Data Scientist                  Data Scientist II
# 282665             Data Scientist    Material Data Specialist(Coupa)
# ...                           ...                                ...
# 413720             Data Scientist              Data Science- GPT/LLM
# 731675       Senior Data Engineer               Senior Data Engineer
# 467337          Software Engineer    Principal iOS Software Engineer
# 731685  Machine Learning Engineer  Machine-Learning-Engineer (m/w/d)
# 573693           Business Analyst                        QA Engineer
#
#                                          job_location            job_via  \
# ...

# %%
df
# Out:
#                   job_title_short                          job_title  \
# 203943             Data Scientist                     Data Scientist
# 282667             Data Scientist                     Data Scientist
# 93472        Senior Data Engineer               Senior Data Engineer
# 93471              Data Scientist                  Data Scientist II
# 282665             Data Scientist    Material Data Specialist(Coupa)
# ...                           ...                                ...
# 413720             Data Scientist              Data Science- GPT/LLM
# 731675       Senior Data Engineer               Senior Data Engineer
# 467337          Software Engineer    Principal iOS Software Engineer
# 731685  Machine Learning Engineer  Machine-Learning-Engineer (m/w/d)
# 573693           Business Analyst                        QA Engineer
#
#                                          job_location            job_via  \
# ...

# %%
df.drop(labels='salary_hour_avg',axis=1,inplace=True)

# %%
df
# Out:
#                   job_title_short                          job_title  \
# 203943             Data Scientist                     Data Scientist
# 282667             Data Scientist                     Data Scientist
# 93472        Senior Data Engineer               Senior Data Engineer
# 93471              Data Scientist                  Data Scientist II
# 282665             Data Scientist    Material Data Specialist(Coupa)
# ...                           ...                                ...
# 413720             Data Scientist              Data Science- GPT/LLM
# 731675       Senior Data Engineer               Senior Data Engineer
# 467337          Software Engineer    Principal iOS Software Engineer
# 731685  Machine Learning Engineer  Machine-Learning-Engineer (m/w/d)
# 573693           Business Analyst                        QA Engineer
#
#                                          job_location            job_via  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 785741 entries, 203943 to 573693
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  company_name           785723 non-null  object
# ...

# %%
df.dropna(subset=['salary_year_avg'])
# Out:
#          job_title_short                                          job_title  \
# 93501       Data Analyst                                Data Analyst, Sales
# 282786      Data Analyst                  Reporting & Data Analysis Manager
# 93002   Business Analyst  Sr. Business Intelligence Analyst - Specialize...
# 92938     Data Scientist                          Healthcare Data Scientist
# 92980     Data Scientist              Lead Associate - Ops (Data Scientist)
# ...                  ...                                                ...
# 467242    Data Scientist       Data Scientist- TikTok Ads, Brand Innovation
# 371559     Data Engineer                                      Data Engineer
# 22113       Data Analyst                                       Data Analyst
# 731735     Data Engineer  Analyst/Associate, Data Engineering- Gen AI, P...
# 644009      Data Analyst                               Senior, Data Analyst
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 785741 entries, 203943 to 573693
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  company_name           785723 non-null  object
# ...

# %%
df.dropna(subset=['salary_year_avg'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22003 entries, 93501 to 644009
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        22003 non-null  object
#  1   job_title              22003 non-null  object
#  2   job_location           21723 non-null  object
#  3   job_via                22003 non-null  object
#  4   job_schedule_type      21987 non-null  object
#  5   job_work_from_home     22003 non-null  bool
#  6   search_location        22003 non-null  object
#  7   job_posted_date        22003 non-null  datetime64[ns]
#  8   job_no_degree_mention  22003 non-null  bool
#  9   job_health_insurance   22003 non-null  bool
#  10  job_country            22003 non-null  object
#  11  salary_rate            22003 non-null  object
#  12  salary_year_avg        22003 non-null  float64
#  13  company_name           22003 non-null  object
# ...

# %%
df.describe()
# Out:
#                      job_posted_date  salary_year_avg  job_posted_date_month
# count                          22003     22003.000000                22003.0
# mean   1970-01-01 00:00:00.000000005    123286.274072                    1.0
# min    1970-01-01 00:00:00.000000001     15000.000000                    1.0
# 25%    1970-01-01 00:00:00.000000003     90000.000000                    1.0
# 50%    1970-01-01 00:00:00.000000006    115000.000000                    1.0
# 75%    1970-01-01 00:00:00.000000008    150000.000000                    1.0
# max    1970-01-01 00:00:00.000000012    960000.000000                    1.0
# std                              NaN     48312.449482                    0.0

# %%
import pandas as pd
from datasets import load_dataset

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
# Data cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.describe()
# Out:
#                      job_posted_date  salary_year_avg  salary_hour_avg
# count                         785741     22003.000000     10662.000000
# mean   2023-06-25 16:02:11.860248576    123286.274072        47.016598
# min              2023-01-01 00:00:04     15000.000000         8.000000
# 25%              2023-03-20 10:05:48     90000.000000        27.500000
# 50%              2023-06-29 06:11:38    115000.000000        45.980000
# 75%              2023-09-27 01:01:16    150000.000000        61.159996
# max              2023-12-31 23:59:58    960000.000000       391.000000
# std                              NaN     48312.449482        21.890738

# %%
 df.count()
# Out:
# job_title_short          785741
# job_title                785740
# job_location             784696
# job_via                  785733
# job_schedule_type        773074
# job_work_from_home       785741
# search_location          785741
# job_posted_date          785741
# job_no_degree_mention    785741
# job_health_insurance     785741
# job_country              785692
# salary_rate               33067
# salary_year_avg           22003
# salary_hour_avg           10662
# company_name             785723
# job_skills               668704
# job_type_skills          668704
# dtype: int64

# %%
df['salary_year_avg'].median()
# Out:
# 115000.0

# %%
df['salary_year_avg'].min()
# Out:
# 15000.0

# %%
min_salary = df['salary_year_avg'].idxmin()

# %%
df.iloc[min_salary]
# Out:
# job_title_short                                              Data Engineer
# job_title                                           Data Engineer - Hadoop
# job_location                                                        Brazil
# job_via                                                       via LinkedIn
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                     Brazil
# job_posted_date                                        2023-12-09 10:05:30
# job_no_degree_mention                                                 True
# job_health_insurance                                                 False
# job_country                                                         Brazil
# salary_rate                                                           year
# ...

# %%
df['job_title_short'].unique()
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
df['job_title_short'].value_counts()
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %%
df.groupby('job_title_short')['salary_year_avg'].min()
# Out:
# job_title_short
# Business Analyst             16500.0
# Cloud Engineer               42000.0
# Data Analyst                 25000.0
# Data Engineer                15000.0
# Data Scientist               27000.0
# Machine Learning Engineer    30000.0
# Senior Data Analyst          30000.0
# Senior Data Engineer         35000.0
# Senior Data Scientist        45000.0
# Software Engineer            28000.0
# Name: salary_year_avg, dtype: float64

# %%
df.groupby('job_title_short')['salary_year_avg'].median()
# Out:
# job_title_short
# Business Analyst              85000.0
# Cloud Engineer                90000.0
# Data Analyst                  90000.0
# Data Engineer                125000.0
# Data Scientist               127500.0
# Machine Learning Engineer    106415.0
# Senior Data Analyst          111175.0
# Senior Data Engineer         147500.0
# Senior Data Scientist        155500.0
# Software Engineer             99150.0
# Name: salary_year_avg, dtype: float64

# %%
df.groupby(['job_title_short','job_country'])['salary_year_avg'].median()
# Out:
# job_title_short    job_country
# Business Analyst   Afghanistan        NaN
#                    Albania            NaN
#                    Algeria            NaN
#                    Angola             NaN
#                    Argentina      71100.0
#                                    ...
# Software Engineer  Venezuela          NaN
#                    Vietnam        53600.0
#                    Yemen              NaN
#                    Zambia             NaN
#                    Zimbabwe           NaN
# Name: salary_year_avg, Length: 1387, dtype: float64

# %%
df.groupby('job_title_short')[['salary_year_avg','salary_hour_avg']].median()
# Out:
#                            salary_year_avg  salary_hour_avg
# job_title_short
# Business Analyst                   85000.0        40.362499
# Cloud Engineer                     90000.0        40.000000
# Data Analyst                       90000.0        32.615002
# Data Engineer                     125000.0        58.500000
# Data Scientist                    127500.0        47.500000
# Machine Learning Engineer         106415.0        47.535000
# Senior Data Analyst               111175.0        47.500000
# Senior Data Engineer              147500.0        61.500000
# Senior Data Scientist             155500.0        47.620003
# Software Engineer                  99150.0        47.560001

# %%
df.groupby('job_title_short')['salary_year_avg'].agg(['min','max','median'])
# Out:
#                                min       max    median
# job_title_short
# Business Analyst           16500.0  387460.0   85000.0
# Cloud Engineer             42000.0  280000.0   90000.0
# Data Analyst               25000.0  650000.0   90000.0
# Data Engineer              15000.0  525000.0  125000.0
# Data Scientist             27000.0  960000.0  127500.0
# Machine Learning Engineer  30000.0  325000.0  106415.0
# Senior Data Analyst        30000.0  425000.0  111175.0
# Senior Data Engineer       35000.0  425000.0  147500.0
# Senior Data Scientist      45000.0  890000.0  155500.0
# Software Engineer          28000.0  375000.0   99150.0

# %%
df['job_country'].value_counts().head(20)
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
# Spain              25100
# Singapore          23696
# Sudan              21781
# Netherlands        20631
# Italy              17013
# Canada             16029
# Mexico             15139
# Poland             14793
# Portugal           14508
# Australia          12955
# South Africa       12414
# Belgium            12078
# Philippines        11786
# Ireland            11162
# Switzerland         9924
# Name: count, dtype: int64

# %%
df['job_country'].isin(['Brazil']).any()
# Out:
# np.True_

# %%
df['job_country'].isin(['South Korea']).any()
# Out:
# np.True_

# %%
india_jobs = df[df['job_country']=='India']

# %%
india_jobs
# Out:
#              job_title_short  \
# 16             Data Engineer
# 19            Data Scientist
# 29            Data Scientist
# 38              Data Analyst
# 42      Senior Data Engineer
# ...                      ...
# 785712         Data Engineer
# 785715          Data Analyst
# 785716     Software Engineer
# 785718      Business Analyst
# 785740     Software Engineer
#
#                                                 job_title  \
# 16                                      Big Data Engineer
# 19                                         Data Scientist
# 29                                         Data Scientist
# 38                  Data Quality and Governance Analyst 1
# 42            Senior Data Engineer(Python)-1563,1637&1633
# ...                                                   ...
# 785712                     India - Collections Analyst II
# 785715  Amul Careers 2023 - Apply Online - Data Analys...
# 785716                        Application Support Analyst
# ...

# %%
india_jobs = india_jobs[india_jobs['salary_year_avg'].notna()]

# %%
india_jobs.groupby('job_title_short')['salary_year_avg'].count()
# Out:
# job_title_short
# Business Analyst               8
# Data Analyst                  94
# Data Engineer                169
# Data Scientist                92
# Machine Learning Engineer     57
# Senior Data Analyst           27
# Senior Data Engineer          57
# Senior Data Scientist         33
# Software Engineer             45
# Name: salary_year_avg, dtype: int64

# %%
india_jobs.groupby('job_title_short')[['salary_year_avg']].min()
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   43200.0
# Data Analyst                       32400.0
# Data Engineer                      43200.0
# Data Scientist                     43200.0
# Machine Learning Engineer          32500.0
# Senior Data Analyst                64800.0
# Senior Data Engineer               35000.0
# Senior Data Scientist              64800.0
# Software Engineer                  44418.5

# %%
india_jobs.groupby('job_title_short')['salary_year_avg'].agg(['median','min','max','count']).sort_values(by='median',ascending=False)
# Out:
#                              median      min       max  count
# job_title_short
# Senior Data Scientist      149653.0  64800.0  170575.0     33
# Senior Data Engineer       147500.0  35000.0  181765.0     57
# Data Engineer              147500.0  43200.0  249000.0    169
# Data Scientist             114008.0  43200.0  204381.0     92
# Senior Data Analyst        111175.0  64800.0  177283.0     27
# Data Analyst               100500.0  32400.0  650000.0     94
# Machine Learning Engineer   79200.0  32500.0  267000.0     57
# Software Engineer           79200.0  44418.5  200000.0     45
# Business Analyst            64800.0  43200.0  142025.0      8
